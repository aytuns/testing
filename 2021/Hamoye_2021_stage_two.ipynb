# %% [markdown]
# ## Importing Initial Necessary Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Reading in, and analysing the CSV file

# %%
df=pd.read_csv('energydata_complete.csv')

# %%
df.head()
# Out:
#                   date  Appliances  lights     T1       RH_1    T2       RH_2  \
# 0  2016-01-11 17:00:00          60      30  19.89  47.596667  19.2  44.790000
# 1  2016-01-11 17:10:00          60      30  19.89  46.693333  19.2  44.722500
# 2  2016-01-11 17:20:00          50      30  19.89  46.300000  19.2  44.626667
# 3  2016-01-11 17:30:00          50      40  19.89  46.066667  19.2  44.590000
# 4  2016-01-11 17:40:00          60      40  19.89  46.333333  19.2  44.530000
#
#       T3       RH_3         T4  ...         T9   RH_9     T_out  Press_mm_hg  \
# 0  19.79  44.730000  19.000000  ...  17.033333  45.53  6.600000        733.5
# 1  19.79  44.790000  19.000000  ...  17.066667  45.56  6.483333        733.6
# 2  19.79  44.933333  18.926667  ...  17.000000  45.50  6.366667        733.7
# 3  19.79  45.000000  18.890000  ...  17.000000  45.40  6.250000        733.8
# 4  19.79  45.000000  18.890000  ...  17.000000  45.40  6.133333        733.9
#
# ...

# %%
df.describe().transpose()
# Out:
#                count        mean         std         min         25%  \
# Appliances   19735.0   97.694958  102.524891   10.000000   50.000000
# lights       19735.0    3.801875    7.935988    0.000000    0.000000
# T1           19735.0   21.686571    1.606066   16.790000   20.760000
# RH_1         19735.0   40.259739    3.979299   27.023333   37.333333
# T2           19735.0   20.341219    2.192974   16.100000   18.790000
# RH_2         19735.0   40.420420    4.069813   20.463333   37.900000
# T3           19735.0   22.267611    2.006111   17.200000   20.790000
# RH_3         19735.0   39.242500    3.254576   28.766667   36.900000
# T4           19735.0   20.855335    2.042884   15.100000   19.530000
# RH_4         19735.0   39.026904    4.341321   27.660000   35.530000
# T5           19735.0   19.592106    1.844623   15.330000   18.277500
# RH_5         19735.0   50.949283    9.022034   29.815000   45.400000
# T6           19735.0    7.910939    6.090347   -6.065000    3.626667
# ...

# %%
df.hist(figsize=(20,10))
plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# ## Dropping the Date Axis

# %%
df=df.drop(['date'],axis =1)

# %%
df.head()
# Out:
#    Appliances  lights     T1       RH_1    T2       RH_2     T3       RH_3  \
# 0          60      30  19.89  47.596667  19.2  44.790000  19.79  44.730000
# 1          60      30  19.89  46.693333  19.2  44.722500  19.79  44.790000
# 2          50      30  19.89  46.300000  19.2  44.626667  19.79  44.933333
# 3          50      40  19.89  46.066667  19.2  44.590000  19.79  45.000000
# 4          60      40  19.89  46.333333  19.2  44.530000  19.79  45.000000
#
#           T4       RH_4  ...         T9   RH_9     T_out  Press_mm_hg  RH_out  \
# 0  19.000000  45.566667  ...  17.033333  45.53  6.600000        733.5    92.0
# 1  19.000000  45.992500  ...  17.066667  45.56  6.483333        733.6    92.0
# 2  18.926667  45.890000  ...  17.000000  45.50  6.366667        733.7    92.0
# 3  18.890000  45.723333  ...  17.000000  45.40  6.250000        733.8    92.0
# 4  18.890000  45.530000  ...  17.000000  45.40  6.133333        733.9    92.0
#
# ...

# %% [markdown]
# ## Normalizing the data

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()
normalised_df = pd.DataFrame(scaler.fit_transform(df), columns=df.columns)

# %%
normalised_df.head()
# Out:
#    Appliances    lights       T1      RH_1        T2      RH_2        T3  \
# 0    0.046729  0.428571  0.32735  0.566187  0.225345  0.684038  0.215188
# 1    0.046729  0.428571  0.32735  0.541326  0.225345  0.682140  0.215188
# 2    0.037383  0.428571  0.32735  0.530502  0.225345  0.679445  0.215188
# 3    0.037383  0.571429  0.32735  0.524080  0.225345  0.678414  0.215188
# 4    0.046729  0.571429  0.32735  0.531419  0.225345  0.676727  0.215188
#
#        RH_3        T4      RH_4  ...        T9      RH_9     T_out  \
# 0  0.746066  0.351351  0.764262  ...  0.223032  0.677290  0.372990
# 1  0.748871  0.351351  0.782437  ...  0.226500  0.678532  0.369239
# 2  0.755569  0.344745  0.778062  ...  0.219563  0.676049  0.365488
# 3  0.758685  0.341441  0.770949  ...  0.219563  0.671909  0.361736
# 4  0.758685  0.341441  0.762697  ...  0.219563  0.671909  0.357985
#
#    Press_mm_hg    RH_out  Windspeed  Visibility  Tdewpoint       rv1       rv2
# ...

# %%
normalised_df.describe().transpose()
# Out:
#                count      mean       std  min       25%       50%       75%  \
# Appliances   19735.0  0.081958  0.095818  0.0  0.037383  0.046729  0.084112
# lights       19735.0  0.054312  0.113371  0.0  0.000000  0.000000  0.000000
# T1           19735.0  0.517061  0.169595  0.0  0.419219  0.507920  0.613516
# RH_1         19735.0  0.364271  0.109512  0.0  0.283735  0.347675  0.441519
# T2           19735.0  0.308303  0.159412  0.0  0.195542  0.283499  0.392537
# RH_2         19735.0  0.561170  0.114438  0.0  0.490299  0.563408  0.641016
# T3           19735.0  0.421038  0.166676  0.0  0.298272  0.407112  0.505982
# RH_3         19735.0  0.489601  0.152107  0.0  0.380122  0.456302  0.607260
# T4           19735.0  0.518499  0.184044  0.0  0.399099  0.501502  0.630631
# RH_4         19735.0  0.485143  0.185289  0.0  0.335894  0.458387  0.618722
# T5           19735.0  0.407272  0.176266  0.0  0.281653  0.387960  0.505460
# ...

# %% [markdown]
# ## Performing Linear Regression on T2 and T6

# %%
X1 = normalised_df[['T2']]
y1 = normalised_df['T6']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(X1,y1, test_size=0.3, random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
linear_model = LinearRegression()

# %%
linear_model.fit(x_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
predicted_values= linear_model.predict(x_test)

# %%
from sklearn import metrics

# %% [markdown]
# ### R^2 Score

# %%
r2_score = metrics.r2_score(y_test, predicted_values)
round(r2_score, 2)
# Out:
# 0.64

# %% [markdown]
# ## Using the full data set

# %% [markdown]
# ### Separating data into Training set, and Testing set

# %%
X = normalised_df.drop('Appliances',axis=1)
y = normalised_df['Appliances']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state=42)

# %% [markdown]
# ## Linear Regression

# %%
from sklearn.linear_model import LinearRegression

# %%
linear_model = LinearRegression()

# %%
linear_model.fit(x_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
predicted_values= linear_model.predict(x_test)

# %% [markdown]
# ### Mean Absolute Error

# %%
mae = metrics.mean_absolute_error(y_test, predicted_values)
round(mae,2)
# Out:
# 0.05

# %% [markdown]
# ### Residual Sum of Squares

# %%
rss = np.sum(np.square(y_test-predicted_values))
round(rss, 2)
# Out:
# 44.37

# %% [markdown]
# ### Root mean squared Error

# %%
rmse = np.sqrt(metrics.mean_squared_error(y_test, predicted_values))
round(rmse, 3)
# Out:
# 0.087

# %% [markdown]
# ### Coefficent of Determination

# %%
r2_score = metrics.r2_score(y_test, predicted_values)
round(r2_score,2)
# Out:
# 0.17

# %% [markdown]
# ## Ridge Regression

# %%
from sklearn.linear_model import Ridge

# %%
ridge_reg = Ridge(alpha=0.4)

# %%
ridge_reg.fit(x_train, y_train)
# Out:
# Ridge(alpha=0.4, copy_X=True, fit_intercept=True, max_iter=None,
#       normalize=False, random_state=None, solver='auto', tol=0.001)

# %%
predicted_values2= ridge_reg.predict(x_test)

# %% [markdown]
# ### Performance of the Ridge Regression

# %%
rmse = np.sqrt(metrics.mean_squared_error(y_test, predicted_values2))
round(rmse, 3)
# Out:
# 0.087

# %% [markdown]
# ## Lasso Regression

# %%
from sklearn.linear_model import Lasso

# %%
lasso_reg = Lasso(alpha=0.001)

# %%
lasso_reg.fit(x_train, y_train)
# Out:
# Lasso(alpha=0.001, copy_X=True, fit_intercept=True, max_iter=1000,
#       normalize=False, positive=False, precompute=False, random_state=None,
#       selection='cyclic', tol=0.0001, warm_start=False)

# %%
predicted_values3= lasso_reg.predict(x_test)

# %% [markdown]
# ### Performance of the Lasso Regression

# %%
rmse = np.sqrt(metrics.mean_squared_error(y_test, predicted_values3))
round(rmse, 3)
# Out:
# 0.092

# %% [markdown]
# ## Comparing The Effects of Regularisation on Feature weights

# %%
def get_weights_df(model, feat, col_name):
  #this function returns the weight of every feature
  weights = pd.Series(model.coef_, feat.columns).sort_values()
  weights_df = pd.DataFrame(weights).reset_index()
  weights_df.columns = ['Features', col_name]
  weights_df[col_name].round(3)
  return weights_df

linear_model_weights = get_weights_df(linear_model, x_train, 'Linear_Model_Weight')
ridge_weights_df = get_weights_df(ridge_reg, x_train, 'Ridge_Weight')
lasso_weights_df = get_weights_df(lasso_reg, x_train, 'Lasso_weight')

final_weights = pd.merge(linear_model_weights, ridge_weights_df, on='Features')
final_weights = pd.merge(final_weights, lasso_weights_df, on='Features')

final_weights
# Out:
#        Features  Linear_Model_Weight  Ridge_Weight  Lasso_weight
# 0          RH_2            -0.425037     -0.382817     -0.000000
# 1         T_out            -0.305942     -0.248559      0.000000
# 2            T2            -0.203519     -0.171618      0.000000
# 3            T9            -0.129547     -0.128990     -0.000000
# 4          RH_8            -0.123726     -0.123087     -0.000000
# 5        RH_out            -0.087518     -0.065093     -0.052519
# 6            T4            -0.039769     -0.040804     -0.000000
# 7          RH_7            -0.036779     -0.038163     -0.000000
# 8          RH_9            -0.026970     -0.028294     -0.000000
# 9          RH_4            -0.019861     -0.020869      0.000000
# 10           T5            -0.015702     -0.019577     -0.000000
# 11           T1            -0.010274     -0.024493      0.000000
# 12          rv1             0.000915      0.000895      0.000000
# ...
