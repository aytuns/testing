# %% [markdown]
# # WORKBOOK TO ANALYSE FOOD BALANCE SHEET

# %%
import numpy as np
import pandas as pd

# %%
food = pd.read_csv('FoodBalanceSheets_E_Africa_NOFLAG.csv', encoding='latin-1')
food.to_csv('FoodBalanceSheets_E_Africa_NOFLAG.csv', index=False)

# %% [markdown]
# ### GET THE FIRST 5 ROWS OF THE FILE

# %%
food.head(5)
# Out:
#    Area Code     Area  Item Code         Item  Element Code
# 0          4  Algeria       2501   Population           511  \
# 1          4  Algeria       2501   Population          5301
# 2          4  Algeria       2901  Grand Total           664
# 3          4  Algeria       2901  Grand Total           674
# 4          4  Algeria       2901  Grand Total           684
#
#                                   Element             Unit     Y2014
# 0           Total Population - Both sexes     1000 persons  38924.00  \
# 1                Domestic supply quantity      1000 tonnes      0.00
# 2           Food supply (kcal/capita/day)  kcal/capita/day   3377.00
# 3  Protein supply quantity (g/capita/day)     g/capita/day     94.90
# 4      Fat supply quantity (g/capita/day)     g/capita/day     80.06
#
#       Y2015     Y2016     Y2017     Y2018
# 0  39728.00  40551.00  41389.00  42228.00
# 1      0.00      0.00      0.00      0.00
# 2   3379.00   3372.00   3341.00   3322.00
# ...

# %%
food.describe(include='all')
# Out:
#            Area Code   Area     Item Code                     Item
# count   60943.000000  60943  60943.000000                    60943  \
# unique           NaN     49           NaN                      119
# top              NaN  Kenya           NaN  Milk - Excluding Butter
# freq             NaN   1560           NaN                     1262
# mean      134.265576    NaN   2687.176706                      NaN
# std        72.605709    NaN    146.055739                      NaN
# min         4.000000    NaN   2501.000000                      NaN
# 25%        74.000000    NaN   2562.000000                      NaN
# 50%       136.000000    NaN   2630.000000                      NaN
# 75%       195.000000    NaN   2775.000000                      NaN
# max       276.000000    NaN   2961.000000                      NaN
#
#         Element Code                   Element         Unit          Y2014
# count   60943.000000                     60943        60943   59354.000000  \
# ...

# %%
food.isnull().sum()
# Out:
# Area Code          0
# Area               0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014           1589
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64

# %% [markdown]
# ### Select columns ‘Y2017’ and ‘Area’, Perform a groupby operation on ‘Area’.  Which of these Areas had the highest sum in 2017?

# %%
food[['Y2017','Area']].groupby('Area').count().sort_values('Y2017',ascending=False).head(5)
# Out:
#                                                     Y2017
# Area
# Kenya                                                1548
# Egypt                                                1458
# Nigeria                                              1457
# CÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃ...   1454
# Senegal                                              1452

# %%
food[['Y2017','Area']].groupby('Area').count().idxmax()
# Out:
# Y2017    Kenya
# dtype: object

# %%
food[['Y2017','Area']].describe()
# Out:
#                Y2017
# count   59437.000000
# mean      140.917765
# std      1671.862359
# min     -1582.000000
# 25%         0.000000
# 50%         0.100000
# 75%         9.000000
# max    190873.000000

# %%
food[['Y2015','Element','Area']].groupby('Element').count()
# Out:
#                                         Y2015  Area
# Element
# Domestic supply quantity                 5245  5295
# Export Quantity                          3704  4403
# Fat supply quantity (g/capita/day)       4974  5023
# Feed                                     1177  1319
# Food                                     4901  4941
# Food supply (kcal/capita/day)            4955  5014
# Food supply quantity (kg/capita/yr)      4865  4905
# Import Quantity                          4911  5139
# Losses                                   2009  2009
# Other uses (non-food)                    1667  1732
# Processing                               1995  2010
# Production                               3828  3881
# Protein supply quantity (g/capita/day)   4971  5023
# Residuals                                4605  4655
# Seed                                      759   762
# Stock Variation                          4229  4232
# Total Population - Both sexes              45    45
# ...

# %% [markdown]
# ### What is the total number and percentage of missing data in 2014 to 3 decimal places?

# %%
totalnull = food.isnull().sum()
totalnullpercent = food.isnull().sum() * 100 / len(food)

print(totalnull,'\n')
print(totalnullpercent)
# Out:
# Area Code          0
# Area               0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014           1589
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64
#
# Area Code       0.000000
# Area            0.000000
# Item Code       0.000000
# Item            0.000000
# Element Code    0.000000
# Element         0.000000
# Unit            0.000000
# Y2014           2.607354
# Y2015           2.540078
# Y2016           2.518747
# Y2017           2.471162
# Y2018           2.356300
# dtype: float64

# %% [markdown]
# ### What is the total sum of Wine produced in 2015 and 2018 respectively?

# %%
food[['Y2015','Y2018','Item']].groupby('Item').sum()
# Out:
#                          Y2015      Y2018
# Item
# Alcohol, Non-Food      2180.00    2293.00
# Alcoholic Beverages   98783.72   97847.27
# Animal Products       11811.73   11578.61
# Animal fats          200675.72  269648.27
# Apples and products   10559.15    9640.51
# ...                        ...        ...
# Vegetables, Other    158104.08  163987.21
# Vegetal Products     107064.17  107775.39
# Wheat and products   234710.51  242645.19
# Wine                   4251.81    4039.32
# Yams                 203151.78  221272.09
#
# [119 rows x 2 columns]

# %%
food.corr(numeric_only=True)
# Out:
#               Area Code  Item Code  Element Code     Y2014     Y2015
# Area Code      1.000000  -0.005159     -0.000209  0.006164  0.005472  \
# Item Code     -0.005159   1.000000     -0.024683  0.021722  0.020857
# Element Code  -0.000209  -0.024683      1.000000  0.024457  0.023889
# Y2014          0.006164   0.021722      0.024457  1.000000  0.994647
# Y2015          0.005472   0.020857      0.023889  0.994647  1.000000
# Y2016          0.005247   0.020109      0.023444  0.996081  0.995739
# Y2017          0.005006   0.021494      0.024254  0.995230  0.988048
# Y2018          0.005665   0.021314      0.024279  0.994872  0.988208
#
#                  Y2016     Y2017     Y2018
# Area Code     0.005247  0.005006  0.005665
# Item Code     0.020109  0.021494  0.021314
# Element Code  0.023444  0.024254  0.024279
# Y2014         0.996081  0.995230  0.994872
# Y2015         0.995739  0.988048  0.988208
# Y2016         1.000000  0.992785  0.992757
# ...

# %%
food[['Element','Y2014','Y2015','Y2016','Y2017','Y2018']].groupby('Element').count()
# Out:
#                                         Y2014  Y2015  Y2016  Y2017  Y2018
# Element
# Domestic supply quantity                 5244   5245   5250   5258   5256
# Export Quantity                          3660   3704   3653   3660   3646
# Fat supply quantity (g/capita/day)       4965   4974   4980   4982   4987
# Feed                                     1216   1177   1215   1213   1225
# Food                                     4896   4901   4910   4912   4913
# Food supply (kcal/capita/day)            4947   4955   4963   4965   4969
# Food supply quantity (kg/capita/yr)      4860   4865   4874   4876   4877
# Import Quantity                          4919   4911   4908   4929   4945
# Losses                                   2009   2009   2009   2009   2008
# Other uses (non-food)                    1662   1667   1634   1619   1655
# Processing                               1987   1995   1996   1998   2003
# Production                               3830   3828   3838   3829   3846
# ...

# %%
food[['Area','Y2017']].groupby('Area').count()
# Out:
#                                                     Y2017
# Area
# Algeria                                              1279
# Angola                                               1407
# Benin                                                1253
# Botswana                                             1368
# Burkina Faso                                         1383
# Cabo Verde                                           1193
# Cameroon                                             1441
# Central African Republic                             1262
# Chad                                                 1281
# Comoros                                                45
# Congo                                                1395
# CÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃ...   1454
# Djibouti                                             1061
# Egypt                                                1458
# Eswatini                                             1251
# ...

# %%
S = [['him', 'sell'], [90, 28, 43]]

S[0][1][1]
# Out:
# 'e'

# %% [markdown]
# ### create a pandas DataFrame using this list

# %%
lst = [[35, 'Portugal', 94], [33, 'Argentina', 93], [30 , 'Brazil', 92]]

col = ['Age','Nationality','Overall']

pd.DataFrame(lst, columns = col, index = [i for i in range(len(lst))])
# Out:
#    Age Nationality  Overall
# 0   35    Portugal       94
# 1   33   Argentina       93
# 2   30      Brazil       92

# %% [markdown]
# ### How would you check for the number of rows and columns in a pandas DataFrame named df?

# %%
food.shape
# Out:
# (60943, 12)

# %%
array  = ([[94, 89, 63],

             [93, 92, 48],

             [92, 94, 56]])
